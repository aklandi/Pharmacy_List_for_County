# %%
from city_list_from_county import get_counties, city_list_from_county
from county_pharmacy_list import county_pharmacy_list

# %% [markdown]
# This is a document is to streamline the whole process!  The overview is
#
# 1. Get names of cities in a US county region.
# 2. Get pharmacies listed in the NPI for that county region.
# 3. Determine the "top" 5 pharmacies for the region.
#
# Code produced by Amanda Landi and Addie Duncan. Last updated: 6/24/2026

# %% [markdown]
# Step 1: Give name of region (county and state) of interest to a function that accesses names of cities in region using OpenStreetMaps.
#
# API key is needed.  Please do not post key anywhere public.

# %%
# store API key in .env file and hide with .gitignore
# use code below to read API key from local .env file
import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()
API_KEY = os.getenv("API_KEY")

# %%
COUNTY_NAME = "Sumter"
STATE_ABBR = "SC"

# %%
city_list = city_list_from_county(API_KEY, COUNTY_NAME, STATE_ABBR)

# %% [markdown]
# Step 2+3: Get a list of pharmacies in these cities (and thus the county) that are listed in the NPI registry.  Note, there may be undercoverage because the NPI may not have the most current information and not all pharmacies may have sent in their information.

# %%
output = county_pharmacy_list(city_list, 75, with_variants = True, with_debug = True)

# %%
# sometimes needed for second or third runs
del output

# %%
top_pharms = output["summary"]
debug_df = output["debug"]

# %%
debug_df
# Out:
#                              name_clean  \
# 22                            walgreens
# 20                             rite aid
# 43                            walgreens
# 42                            walgreens
# 41                             rite aid
# 24                             rite aid
# 23                            walgreens
# 21                            walgreens
# 44                             rite aid
# 18                              walmart
# 17                              walmart
# 39                              walmart
# 40                              walmart
# 36                                  cvs
# 19                              walmart
# 37                                  cvs
# 38                                  cvs
# 12                                  cvs
# 11                                  cvs
# 7                                   sup
# 6                                   sup
# 5                                 suprx
# 14                  sumter cut rate inc
# 13             sumter cut rate drug llc
# 35  self regional healthcare outpatient
# 34      self regional healthcare epting
# 9                              rite aid
# 4                          phillips inc
# 32                               publix
# 3                                 court
# 2                                prisma
# 33                 dhec region district
# 27                   carolina northwest
# 31                        piggly wiggly
# 30      greenwood treatment specialists
# 29        greenwood family practice inc
# 28                            food lion
# 10                            sandhills
# 26                             carolina
# 25                             wingards
# 1                         christmas llc
# 8                     prescriptions inc
# 16                               tandem
# 15                        sumter family
# 0                     alderman drug inc
#
#                                   AddressLocation  \
# 22           201 N LAFAYETTE DR, SUMTER, SC 29150
# 20          225 N WASHINGTON ST, SUMTER, SC 29150
# 43            1376 MAIN ST S, GREENWOOD, SC 29646
# 42         1014 MONTAGUE AVE, GREENWOOD, SC 29649
# 41           311 HAMPTON AVE, GREENWOOD, SC 29646
# 24              375 PINEWOOD RD, SUMTER, SC 29150
# 23                1000 BROAD ST, SUMTER, SC 29150
# 21         1990 MCCRAYS MILL RD, SUMTER, SC 29150
# 44            1400 MAIN ST S, GREENWOOD, SC 29646
# 18               615 BULTMAN DR, SUMTER, SC 29150
# 17              337 PINEWOOD RD, SUMTER, SC 29150
# 39          300 BYPASS 25 NE, GREENWOOD, SC 29646
# 40          508 BYPASS 72 NW, GREENWOOD, SC 29649
# 36            1337 S MAIN ST, GREENWOOD, SC 29646
# 19                1283 BROAD ST, SUMTER, SC 29150
# 37     1302 HIGHWAY 72 221 E, GREENWOOD, SC 29649
# 38  1942 MONTAGUE AVENUE EXT, GREENWOOD, SC 29649
# 12              41 E CALHOUN ST, SUMTER, SC 29150
# 11                1080 ALICE DR, SUMTER, SC 29150
# 7            1455 S GUIGNARD DR, SUMTER, SC 29150
# 6                 1011 BROAD ST, SUMTER, SC 29150
# 5              114 E CALHOUN ST, SUMTER, SC 29150
# 14                 26 S MAIN ST, SUMTER, SC 29150
# 13                 32 S MAIN ST, SUMTER, SC 29150
# 35            1325 SPRING ST, GREENWOOD, SC 29646
# 34            520 EPTING AVE, GREENWOOD, SC 29646
# 9                 1077 BROAD ST, SUMTER, SC 29150
# 4                1087C ALICE DR, SUMTER, SC 29150
# 32          479 BYPASS 72 NW, GREENWOOD, SC 29649
# 3              776 W LIBERTY ST, SUMTER, SC 29150
# 2                 216 N MAIN ST, SUMTER, SC 29150
# 33            1736 S MAIN ST, GREENWOOD, SC 29646
# 27      577 BYPASS HWY 72 NW, GREENWOOD, SC 29649
# 31     3353 HIGHWAY 72 221 E, GREENWOOD, SC 29649
# 30           110 COURT AVE W, GREENWOOD, SC 29646
# 29            1226 SPRING ST, GREENWOOD, SC 29646
# 28         1605 BYPASS 72 NE, GREENWOOD, SC 29649
# 10              425 N SALEM AVE, SUMTER, SC 29150
# 26            420 EPTING AVE, GREENWOOD, SC 29646
# 25          202 SEABOARD AVE, GREENWOOD, SC 29646
# 1                 1229 ALICE DR, SUMTER, SC 29150
# 8             240 CHURCH STREET, SUMTER, SC 29150
# 16                 368 S PIKE W, SUMTER, SC 29150
# 15          1278 N LAFAYETTE DR, SUMTER, SC 29150
# 0                  40 N MAIN ST, SUMTER, SC 29150
#
#                                AddressMailing  \
# 22     1901 E VOORHEES ST, DANVILLE, IL 61834
# 20     1901 E VOORHEES ST, DANVILLE, IL 61834
# 43     1901 E VOORHEES ST, DANVILLE, IL 61834
# 42     1901 E VOORHEES ST, DANVILLE, IL 61834
# 41     1901 E VOORHEES ST, DANVILLE, IL 61834
# 24     1901 E VOORHEES ST, DANVILLE, IL 61834
# 23     1901 E VOORHEES ST, DANVILLE, IL 61834
# 21     1901 E VOORHEES ST, DANVILLE, IL 61834
# 44     1901 E VOORHEES ST, DANVILLE, IL 61834
# 18       702 SW 8TH ST, BENTONVILLE, AR 72716
# 17       702 SW 8TH ST, BENTONVILLE, AR 72716
# 39       702 SW 8TH ST, BENTONVILLE, AR 72716
# 40       702 SW 8TH ST, BENTONVILLE, AR 72716
# 36             1 CVS DR, WOONSOCKET, RI 02895
# 19       702 SW 8TH ST, BENTONVILLE, AR 72716
# 37             1 CVS DR, WOONSOCKET, RI 02895
# 38             1 CVS DR, WOONSOCKET, RI 02895
# 12             1 CVS DR, WOONSOCKET, RI 02895
# 11             1 CVS DR, WOONSOCKET, RI 02895
# 7        1455 S GUIGNARD DR, SUMTER, SC 29150
# 6             1011 BROAD ST, SUMTER, SC 29150
# 5          114 E CALHOUN ST, SUMTER, SC 29150
# 14             32 S MAIN ST, SUMTER, SC 29150
# 13             32 S MAIN ST, SUMTER, SC 29150
# 35        1325 SPRING ST, GREENWOOD, SC 29646
# 34         104 WELLS AVE, GREENWOOD, SC 29646
# 9             1077 BROAD ST, SUMTER, SC 29150
# 4     1167 COLE MILL RD, TURBEVILLE, SC 29162
# 32        PO BOX 639680, CINCINNATI, OH 45263
# 3          776 W LIBERTY ST, SUMTER, SC 29150
# 2     1 INDEPENDENCE PT, GREENVILLE, SC 29615
# 33        1751 CALHOUN ST, COLUMBIA, SC 29201
# 27  577 BYPASS HWY 72 NW, GREENWOOD, SC 29649
# 31        PO BOX 118047, CHARLESTON, SC 29423
# 30      200 WELLING CIR, GREENVILLE, SC 29607
# 29     333 PLANTATION DR, GREENWOOD, SC 29649
# 28            PO BOX 1000, PORTLAND, ME 04104
# 10          425 N SALEM AVE, SUMTER, SC 29150
# 26           313 MAIN ST, GREENWOOD, SC 29646
# 25            PO BOX 660, GREENWOOD, SC 29648
# 1             1229 ALICE DR, SUMTER, SC 29150
# 8         240 CHURCH STREET, SUMTER, SC 29150
# 16      1278 N LAFAYETTE DR, SUMTER, SC 29150
# 15               PO BOX 250, SUMTER, SC 29151
# 0              40 N MAIN ST, SUMTER, SC 29150
#
#                                             merge_log
# 22               [mailing_merge:walgreens + rite aid]
# 20                                                 []
# 43               [mailing_merge:walgreens + rite aid]
# 42               [mailing_merge:walgreens + rite aid]
# 41                [mailing_merge:rite aid + rite aid]
# 24                [mailing_merge:rite aid + rite aid]
# 23               [mailing_merge:walgreens + rite aid]
# 21               [mailing_merge:walgreens + rite aid]
# 44                [mailing_merge:rite aid + rite aid]
# 18                  [mailing_merge:walmart + walmart]
# 17                                                 []
# 39                  [mailing_merge:walmart + walmart]
# 40                  [mailing_merge:walmart + walmart]
# 36                          [mailing_merge:cvs + cvs]
# 19                  [mailing_merge:walmart + walmart]
# 37                          [mailing_merge:cvs + cvs]
# 38                          [mailing_merge:cvs + cvs]
# 12                          [mailing_merge:cvs + cvs]
# 11                                                 []
# 7              [fuzzy_merge:sup + suprx (score=75.0)]
# 6              [fuzzy_merge:sup + suprx (score=75.0)]
# 5                                                  []
# 14  [mailing_merge:sumter cut rate inc + sumter cu...
# 13                                                 []
# 35                                                 []
# 34                                                 []
# 9                                                  []
# 4                                                  []
# 32                                                 []
# 3                                                  []
# 2                                                  []
# 33                                                 []
# 27                                                 []
# 31                                                 []
# 30                                                 []
# 29                                                 []
# 28                                                 []
# 10                                                 []
# 26                                                 []
# 25                                                 []
# 1                                                  []
# 8                                                  []
# 16                                                 []
# 15                                                 []
# 0                                                  []
